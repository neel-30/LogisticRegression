# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/neela/Downloads/bank-additional-full-1.csv",sep=';')

# %%
df.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41199, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
df.isnull().sum()  #checking null values
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
df.dropna(inplace=True)  #removing null values

# %%
df.duplicated().sum()  #checking duplicates
# Out:
# 13

# %%
df.drop_duplicates(inplace=True)  #removing duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.columns:
    if (df[i].dtypes!='object'):
        plt.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
df.corr()
# Out:
# C:\Users\neela\AppData\Local\Temp\ipykernel_4964\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000818  0.004640 -0.034345  0.024580
# duration       -0.000818  1.000000 -0.071765 -0.047557  0.020596
# campaign        0.004640 -0.071765  1.000000  0.052607 -0.079173
# pdays          -0.034345 -0.047557  0.052607  1.000000 -0.587480
# previous        0.024580  0.020596 -0.079173 -0.587480  1.000000
# emp.var.rate   -0.000337 -0.027939  0.150782  0.271057 -0.420600
# cons.price.idx  0.001268  0.005299  0.127827  0.078926 -0.203096
# cons.conf.idx   0.128745 -0.008121 -0.013664 -0.091379 -0.051014
# euribor3m       0.010660 -0.032857  0.135160  0.296931 -0.454604
# ...

# %%
fig=plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder   #changing object data type to numeric datatype

# %%
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41177 entries, 0 to 41193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41177 non-null  float64
#  1   job             41177 non-null  int32
#  2   marital         41177 non-null  int32
#  3   education       41177 non-null  int32
#  4   default         41177 non-null  int32
#  5   housing         41177 non-null  int32
#  6   loan            41177 non-null  int32
#  7   contact         41177 non-null  int32
#  8   month           41177 non-null  int32
#  9   day_of_week     41177 non-null  int32
#  10  duration        41177 non-null  float64
#  11  campaign        41177 non-null  float64
#  12  pdays           41177 non-null  float64
#  13  previous        41177 non-null  float64
#  14  poutcome        41177 non-null  int32
#  15  emp.var.rate    41177 non-null  float64
#  16  cons.price.idx  41177 non-null  float64
# ...

# %%
x=df.iloc[: ,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
rfe=RFE(model)

# %%
rfe.fit(x,y)
# Out:
# C:\Users\neela\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\neela\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
col_names=x.columns

# %%
select_indices=[i for i ,data in enumerate(rfe.support_) if data==True]

# %%
select_indices
# Out:
# [2, 4, 7, 8, 9, 11, 13, 14, 17, 18]

# %%
selected_cols=[col_names[i] for i in select_indices]
selected_cols
# Out:
# ['marital',
#  'default',
#  'contact',
#  'month',
#  'day_of_week',
#  'campaign',
#  'previous',
#  'poutcome',
#  'cons.conf.idx',
#  'euribor3m']

# %%
x=x.loc[:,selected_cols]
x
# Out:
#        marital  default  contact  month  day_of_week  campaign  previous  \
# 0            1        0        1      6            1       1.0       0.0
# 1            1        1        1      6            1       1.0       0.0
# 2            1        0        1      6            1       1.0       0.0
# 3            1        0        1      6            1       1.0       0.0
# 4            1        0        1      6            1       1.0       0.0
# ...        ...      ...      ...    ...          ...       ...       ...
# 41184        1        0        0      7            0       1.0       0.0
# 41185        1        0        0      7            0       2.0       0.0
# 41186        1        0        0      7            0       1.0       0.0
# 41187        1        0        0      7            0       3.0       1.0
# 41193        1        0        0      7            0       3.0       1.0
#
#        poutcome  cons.conf.idx  euribor3m
# 0             1          -36.4      4.857
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=.80,random_state=0)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\neela\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ans=lr.predict(x_test)

# %%
ans
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import*

# %%
accuracy_score(ans,y_test)  #90%accuracy
# Out:
# 0.9004371053909664

# %%
confusion_matrix(ans,y_test)
# Out:
# array([[7246,  748],
#        [  72,  170]], dtype=int64)

# %%
report=classification_report(ans,y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      7994
#            1       0.19      0.70      0.29       242
#
#     accuracy                           0.90      8236
#    macro avg       0.59      0.80      0.62      8236
# weighted avg       0.97      0.90      0.93      8236
